# %% [raw]
# ---
# title: "Your Title Here"
# status: seed
# categories: [Ship Note]
# draft: true
# ---
#
# <!-- Status options: seed | developing | mature -->
# <!-- Categories: Mental Model, Ship Note -->
# <!-- Remove draft: true when ready to publish -->

# %% [markdown]
# ## The Problem
#
# What you were trying to solve.

# %%
# Setup

# %% [markdown]
# ## What I Learned
#
# Key takeaways anchored to the real problem.
